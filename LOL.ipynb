# %%
from ultralytics import YOLO

# %%
yolo = YOLO('yolov5s.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:04<00:00, 4.06MB/s]

# %%
yolo.val()
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.9.6 torch-2.3.0 CPU (Apple M1)
# YOLOv5s summary (fused): 193 layers, 9,142,496 parameters, 0 gradients, 24.0 GFLOPs
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/Users/mattiacarolo/Documents/GitHub/DL2023-Carolo-Maines/datasets/coco/val2017.txt'
# ...
#   4%|▎         | 6.00M/169M [00:01<00:42, 3.99MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 yolo.val()
#
# File ~/.pyenv/versions/3.9.6/envs/bagigio/lib/python3.9/site-packages/ultralytics/engine/model.py:646, in Model.val(self, validator, **kwargs)
#     643 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     645 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 646 validator(model=self.model)
#     647 self.metrics = validator.metrics
# ...
